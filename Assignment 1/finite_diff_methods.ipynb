# %%
import numpy as np
import sympy as smb
import matplotlib.pyplot as plt

# %%
h = smb.symbols('h')
A = smb.Matrix(5,5, lambda i,j: (4-j)**i)
b = smb.Matrix(5,1, [0,0,2*h**-2,0,0])

# %%
smb.linsolve((A, b))
# Out:
# {(11/(12*h**2), -14/(3*h**2), 19/(2*h**2), -26/(3*h**2), 35/(12*h**2))}
