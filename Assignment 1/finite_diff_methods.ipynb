# %%
import numpy as np
import sympy as smb
import matplotlib.pyplot as plt
smb.init_printing()

# %%
h = smb.symbols('h')
A = smb.Matrix(5,5, lambda i,j: (4-j)**i)
b = smb.Matrix(5,1, [0,0,2*h**-2,0,0])

# %%
smb.linsolve((A, b))
# Out:
# ⎧⎛ 11    -14    19   -26    35  ⎞⎫
# ⎪⎜─────, ────, ────, ────, ─────⎟⎪
# ⎨⎜    2     2     2     2      2⎟⎬
# ⎪⎝12⋅h   3⋅h   2⋅h   3⋅h   12⋅h ⎠⎪
# ⎩                                ⎭

# %%
u = smb.Function('u')
x = smb.symbols('x')

# %%
A = smb.Matrix(5,5, [1,1,1,1,1,-2,-1,0,1,2,4,1,0,1,4,-8,-1,0,1,8,16,1,0,1,16])
b = smb.Matrix(5,1, [0,0,2*h**-2,0,0])
A,b
# Out:
# ⎛                    ⎡0 ⎤⎞
# ⎜                    ⎢  ⎥⎟
# ⎜⎡1   1   1  1  1 ⎤  ⎢0 ⎥⎟
# ⎜⎢                ⎥  ⎢  ⎥⎟
# ⎜⎢-2  -1  0  1  2 ⎥  ⎢2 ⎥⎟
# ⎜⎢                ⎥  ⎢──⎥⎟
# ⎜⎢4   1   0  1  4 ⎥, ⎢ 2⎥⎟
# ⎜⎢                ⎥  ⎢h ⎥⎟
# ⎜⎢-8  -1  0  1  8 ⎥  ⎢  ⎥⎟
# ⎜⎢                ⎥  ⎢0 ⎥⎟
# ⎜⎣16  1   0  1  16⎦  ⎢  ⎥⎟
# ⎝                    ⎣0 ⎦⎠

# %%
smb.linsolve((A,b)).args[0]
# Out:
# ⎛ -1     4    -5     4     -1  ⎞
# ⎜─────, ────, ────, ────, ─────⎟
# ⎜    2     2     2     2      2⎟
# ⎝12⋅h   3⋅h   2⋅h   3⋅h   12⋅h ⎠

# %%
for c in _:
    print((c*h**2).evalf())
# Out:
# -0.0833333333333333
# 1.33333333333333
# -2.50000000000000
# 1.33333333333333
# -0.0833333333333333
