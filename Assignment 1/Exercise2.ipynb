# %%
import numpy as np
from scipy.sparse import spdiags, eye, kron
from scipy.sparse.linalg import spsolve
import matplotlib.pyplot as plt

def u_func(x,y):
    return np.sin(4*np.pi*(x+y)) + np.cos(4*np.pi*x*y)

def f_func(x,y):
    term1 = -32*np.pi**2*np.sin(4*np.pi*(x+y))
    term2 = -16*np.pi**2*(x**2 + y**2)*np.cos(4*np.pi*x*y)
    return term1 + term2


def poisson5(m):
    e = np.ones(m)
    S = spdiags([e, -2*e, e], [-1, 0, 1], m, m)
    I = eye(m, format='csr')
    A = kron(I, S) + kron(S, I)
    A = (m + 1)**2 * A
    return A.tocsr()

def form_rhs(m, f_func, u_func):

    h = 1.0/(m+1)
    b = np.zeros(m*m)

    for j in range(1, m+1):
        for i in range(1, m+1):

            k = (j-1)*m + (i-1)
            x = i*h
            y = j*h

            b[k] = f_func(x,y)

            # left boundary
            if i == 1:
                b[k] -= u_func(0,y)/h**2

            # right boundary
            if i == m:
                b[k] -= u_func(1,y)/h**2

            # bottom boundary
            if j == 1:
                b[k] -= u_func(x,0)/h**2

            # top boundary
            if j == m:
                b[k] -= u_func(x,1)/h**2

    return b

# %%
hs = []
errs = []

for i in range(1,9):
    h = (1/2)**i
    m = int(1.0/h-1)
    
    A = poisson5(m).tocsr()          
    F = form_rhs(m,f_func,u_func)
    
    v = spsolve(A, F)
    
    x_interior = np.linspace(h, 1-h, m)
    y_interior = np.linspace(h, 1-h, m)
    X, Y = np.meshgrid(x_interior, y_interior, indexing='ij')
    U_exact = u_func(X, Y)
    
    err = v - U_exact.flatten()
    l2err = np.sqrt(h**2 * np.sum(err**2))
    
    hs.append(h)
    errs.append(l2err)

plt.loglog(hs, errs, 'o-')
plt.xlabel("h")
plt.ylabel("L2 error")
plt.grid(True, which='both')
plt.show()

# %%
np.polyfit(np.log(hs[3:]),np.log(errs[3:]),1)
# Out:
# array([2.01067212, 2.14487385])

# %%
def poisson9(m):
    e = np.ones(m)
    S = spdiags([-e, -10*e, -e], [-1, 0, 1], m, m)
    I = spdiags([-0.5*e, e, -0.5*e], [-1, 0, 1], m, m)
    A = (1/6) * (m + 1)**2 * (kron(I, S) + kron(S, I))
    return A.tocsr()

def laplace_f(x,y):
    term1 = 1024*np.pi**4*np.sin(4*np.pi*(x+y))
    term2a = -64*np.pi**2*np.cos(4*np.pi*x*y)
    term2b = 512*np.pi**3*x*y*np.sin(4*np.pi*x*y)
    term2c = 256*np.pi**4*(x**2+y**2)**2*np.cos(4*np.pi*x*y)
    return term1 + term2a + term2b + term2c

def form_rhs9(m, f_func, u_func):
    h = 1.0/(m+1)
    b = np.zeros(m*m)

    w_axial  = 4 / (6 * h**2)
    w_corner = 1 / (6 * h**2)

    for j in range(1, m+1):
        for i in range(1, m+1):
            k = (j-1)*m + (i-1)
            x = i*h
            y = j*h
            b[k] = f_func(x,y) +h**2/12 * laplace_f(x,y)

            # ---- Axial neighbors ----
            if i == 1:      # left
                b[k] -= w_axial * u_func(0, y)
            if i == m:      # right
                b[k] -= w_axial * u_func(1, y)
            if j == 1:      # bottom
                b[k] -= w_axial * u_func(x, 0)
            if j == m:      # top
                b[k] -= w_axial * u_func(x, 1)

            # ---- Diagonal neighbors ----
            # left side
            if i == 1:
                if j > 1:   # bottom-left diagonal
                    b[k] -= w_corner * u_func(0, (j-1)*h)
                if j < m:   # top-left diagonal
                    b[k] -= w_corner * u_func(0, (j+1)*h)

            # right side
            if i == m:
                if j > 1:
                    b[k] -= w_corner * u_func(1, (j-1)*h)
                if j < m:
                    b[k] -= w_corner * u_func(1, (j+1)*h)

            # bottom side
            if j == 1:
                if i > 1:
                    b[k] -= w_corner * u_func((i-1)*h, 0)
                if i < m:
                    b[k] -= w_corner * u_func((i+1)*h, 0)

            # top side
            if j == m:
                if i > 1:
                    b[k] -= w_corner * u_func((i-1)*h, 1)
                if i < m:
                    b[k] -= w_corner * u_func((i+1)*h, 1)

    return b

# %%
hs = []
l2errs = []
linferrs = []

for i in range(1,6):
    h = (1/2)**i
    m = int(1.0/h-1)
    
    A = poisson9(m)    
    F = form_rhs9(m,f_func,u_func)
    
    v = spsolve(A, F)
    
    x_interior = np.linspace(h, 1-h, m)
    y_interior = np.linspace(h, 1-h, m)
    X, Y = np.meshgrid(x_interior, y_interior, indexing='ij')
    U_exact = u_func(X, Y)
    
    err = v - U_exact.flatten()
    l2err = np.sqrt(h**2*np.sum(err**2))
    linferr = np.max(err)
    
    hs.append(h)
    l2errs.append(l2err)
    linferrs.append(linferr)

plt.loglog(hs, l2errs, 'o-',label="l_2")
plt.loglog(hs, linferrs, 'o-',label="l_inf")
plt.xlabel("h")
plt.ylabel("Error")
plt.grid(True, which='both')
plt.legend()
plt.show()

# %%
np.polyfit(np.log(hs[3:]),np.log(l2errs[3:]),1)
# Out:
# array([ 0.16851884, -1.41886178])

# %%
np.polyfit(np.log(hs[3:]),np.log(linferrs[3:]),1)
# Out:
# array([ 6.13296869, 11.67298601])
